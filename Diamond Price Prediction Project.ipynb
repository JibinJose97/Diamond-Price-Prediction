# %% [markdown]
# # Diamond Price Prediction Analayization Visualization and Prediction

# %% [markdown]
# # Analayzation using Pandas

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing dataset
data=pd.read_csv("diamonds1.csv")
data
# Out:
#           no  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935  53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936  53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937  53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# ...

# %%
# 0 : No - Index Number
# 1 : carat - Carat weight of the diamond
# 2 : cut - Describe cut quality of the diamond. Quality in increasing order Fair, Good, Very Good, Premium, Ideal
# 3 : color - Color of the diamond, with D being the best and J the worst
# 4 : clarity - How obvious inclusions are within the diamond:
#               (in order from best to worst, FL = flawless, I3= level 3 inclusions)
#                FL,IF, VVS1, VVS2, VS1, VS2, SI1, SI2, I1, I2, I3
# 5 : depth - The height of a diamond, measured from the culet to the table, divided by its average girdle diameter
# 6 : table - The width of the diamond's table expressed as a percentage of its average diameter
# 7 : price - The price of the diamond
# 8 : x - Length mm
# 9 : y - Width mm
# 10 : z - Depth in mm

# %%
# To find the number of rows
data.shape[0]
# Out:
# 53940

# %%
# To find the number of columns
data.shape[1]
# Out:
# 11

# %%
#To get the full information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   no       53940 non-null  int64
#  1   carat    53940 non-null  float64
#  2   cut      53940 non-null  object
#  3   color    53940 non-null  object
#  4   clarity  53940 non-null  object
#  5   depth    53940 non-null  float64
#  6   table    53940 non-null  float64
#  7   price    53940 non-null  int64
#  8   x        53940 non-null  float64
#  9   y        53940 non-null  float64
#  10  z        53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
# This method returns description of the data
data.describe()
# Out:
#                  no         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
# To print the first five values
data.head()
# Out:
#    no  carat      cut color clarity  depth  table  price     x     y     z
# 0   1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# To print the first ten values
data.head(10)
# Out:
#    no  carat        cut color clarity  depth  table  price     x     y     z
# 0   1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   9   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9  10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
# To print last five values
data.tail()
# Out:
#           no  carat        cut color clarity  depth  table  price     x     y  \
# 53935  53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936  53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937  53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 53935  3.50
# 53936  3.61
# 53937  3.56
# 53938  3.74
# 53939  3.64

# %%
# To print last ten values
data.tail(10)
# Out:
#           no  carat        cut color clarity  depth  table  price     x     y  \
# 53930  53931   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74
# 53931  53932   0.71    Premium     F     SI1   59.8   62.0   2756  5.74  5.73
# 53932  53933   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76
# 53933  53934   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72
# 53934  53935   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73
# 53935  53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936  53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937  53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 53930  3.49
# 53931  3.43
# 53932  3.47
# 53933  3.49
# 53934  3.58
# 53935  3.50
# 53936  3.61
# ...

# %%
# To get unique value of column cut
data["cut"].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
# To find the number of unique items in column cut
data["cut"].nunique()
# Out:
# 5

# %%
# To find how many times a value in a particular column repeats
data["cut"].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
# To find the minimum value of the column carat
data["carat"].min()
# Out:
# 0.2

# %%
# To find the index number of the minimum value in column carat
data["carat"].idxmin()
# Out:
# 14

# %%
# To find the maximum values of the column carat
data["carat"].max()
# Out:
# 5.01

# %%
# To find the index number of the maximum value in column carat
data["carat"].idxmax()
# Out:
# 27415

# %%
# To print the whole data of minimum and maximum values
data.loc[[14,27415],["no","carat","cut","color","clarity","depth","table","price","x","y","z"]]
# Out:
#           no  carat      cut color clarity  depth  table  price      x      y  \
# 14        15   0.20  Premium     E     SI2   60.2   62.0    345   3.79   3.75
# 27415  27416   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54
#
#           z
# 14     2.27
# 27415  6.98

# %%
# Slicing 1000 rows using iloc
data.iloc[:1000,:]
# Out:
#        no  carat      cut color clarity  depth  table  price     x     y     z
# 0       1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ..    ...    ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 995   996   0.54    Ideal     D    VVS2   61.4   52.0   2897  5.30  5.34  3.26
# 996   997   0.72    Ideal     E     SI1   62.5   55.0   2897  5.69  5.74  3.57
# 997   998   0.72     Good     F     VS1   59.4   61.0   2897  5.82  5.89  3.48
# 998   999   0.74  Premium     D     VS2   61.8   58.0   2897  5.81  5.77  3.58
# 999  1000   1.12  Premium     J     SI2   60.6   59.0   2898  6.68  6.61  4.03
#
# ...

# %%
# Accessing a column from the data
data["table"]
# Out:
# 0        55.0
# 1        61.0
# 2        65.0
# 3        58.0
# 4        58.0
#          ...
# 53935    57.0
# 53936    55.0
# 53937    60.0
# 53938    58.0
# 53939    55.0
# Name: table, Length: 53940, dtype: float64

# %%
# To print the smallest ten values from column depth
data["depth"].nsmallest(10)
# Out:
# 4518     43.0
# 10377    43.0
# 6341     44.0
# 16857    50.8
# 36503    51.0
# 47775    52.2
# 40766    52.3
# 42256    52.7
# 713      53.0
# 443      53.1
# Name: depth, dtype: float64

# %%
# To print the largest ten values from column depth
data["depth"].nlargest(10)
# Out:
# 52860    79.0
# 52861    79.0
# 41918    78.2
# 46679    73.6
# 53540    72.9
# 51928    72.2
# 8672     71.8
# 4307     71.6
# 45688    71.6
# 8186     71.3
# Name: depth, dtype: float64

# %%
# To print the whole data of ten smallest
data.nsmallest(10,"depth")
# Out:
#           no  carat    cut color clarity  depth  table  price     x     y  \
# 4518    4519   1.00   Fair     G     SI1   43.0   59.0   3634  6.32  6.27
# 10377  10378   1.09  Ideal     J     VS2   43.0   54.0   4778  6.53  6.55
# 6341    6342   1.00   Fair     G     VS2   44.0   53.0   4032  6.31  6.24
# 16857  16858   1.43   Fair     I     VS1   50.8   60.0   6727  7.73  7.25
# 36503  36504   0.30   Fair     E    VVS2   51.0   67.0    945  4.67  4.62
# 47775  47776   0.70   Fair     D     SI1   52.2   65.0   1895  6.04  5.99
# 40766  40767   0.37   Fair     F      IF   52.3   61.0   1166  4.96  4.91
# 42256  42257   0.56   Fair     H     VS2   52.7   70.0   1293  5.71  5.57
# 713      714   1.02   Fair     I     SI1   53.0   63.0   2856  6.84  6.77
# 443      444   0.96   Fair     E     SI2   53.1   63.0   2815  6.73  6.65
#
#           z
# 4518   3.97
# 10377  4.12
# 6341   4.12
# 16857  3.93
# 36503  2.37
# 47775  3.14
# 40766  2.58
# 42256  2.97
# 713    3.66
# 443    3.55

# %%
# To print the whole data of ten largest
data.nlargest(10,"depth")
# Out:
#           no  carat   cut color clarity  depth  table  price     x     y     z
# 52860  52861   0.50  Fair     E     VS2   79.0   73.0   2579  5.21  5.18  4.09
# 52861  52862   0.50  Fair     E     VS2   79.0   73.0   2579  5.21  5.18  4.09
# 41918  41919   1.03  Fair     E      I1   78.2   54.0   1262  5.72  5.59  4.42
# 46679  46680   0.99  Fair     J      I1   73.6   60.0   1789  6.01  5.80  4.35
# 53540  53541   0.90  Fair     G     SI1   72.9   54.0   2691  5.74  5.67  4.16
# 51928  51929   0.96  Fair     G     SI2   72.2   56.0   2438  6.01  5.81  4.28
# 8672    8673   1.02  Fair     H     VS1   71.8   56.0   4455  6.04  5.97  4.31
# 4307    4308   0.99  Fair     H     VS2   71.6   57.0   3593  5.94  5.80  4.20
# 45688  45689   0.70  Fair     D     SI2   71.6   55.0   1696  5.47  5.28  3.85
# 8186    8187   1.50  Fair     I      I1   71.3   58.0   4368  6.85  6.81  4.87

# %%
# Sorting the values in ascending order using the column price
data.sort_values(by=["price"])
# Out:
#           no  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 27745  27746   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00
# 27746  27747   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13
# 27747  27748   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41
# 27748  27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97
# 27749  27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47
#
#           z
# 0      2.43
# ...

# %%
# Grouping data using column cut
group=data.groupby(["cut"])
group
group.get_group("Good")
# Out:
#           no  carat   cut color clarity  depth  table  price     x     y     z
# 2          3   0.23  Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4          5   0.31  Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 10        11   0.30  Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 17        18   0.30  Good     J     SI1   63.4   54.0    351  4.23  4.29  2.70
# 18        19   0.30  Good     J     SI1   63.8   56.0    351  4.23  4.26  2.71
# ...      ...    ...   ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53913  53914   0.80  Good     G     VS2   64.2   58.0   2753  5.84  5.81  3.74
# 53914  53915   0.84  Good     I     VS1   63.7   59.0   2753  5.94  5.90  3.77
# 53916  53917   0.74  Good     D     SI1   63.1   59.0   2753  5.71  5.74  3.61
# 53927  53928   0.79  Good     F     SI1   58.1   59.0   2756  6.06  6.13  3.54
# 53936  53937   0.72  Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
#
# ...

# %%
# Printing data from the group Ideal
group.get_group("Ideal")
# Out:
#           no  carat    cut color clarity  depth  table  price     x     y  \
# 0          1   0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 11        12   0.23  Ideal     J     VS1   62.8   56.0    340  3.93  3.90
# 13        14   0.31  Ideal     J     SI2   62.2   54.0    344  4.35  4.37
# 16        17   0.30  Ideal     I     SI2   62.0   54.0    348  4.31  4.34
# 39        40   0.33  Ideal     I     SI2   61.8   55.0    403  4.49  4.51
# ...      ...    ...    ...   ...     ...    ...    ...    ...   ...   ...
# 53925  53926   0.79  Ideal     I     SI1   61.6   56.0   2756  5.95  5.97
# 53926  53927   0.71  Ideal     E     SI1   61.9   56.0   2756  5.71  5.73
# 53929  53930   0.71  Ideal     G     VS1   61.4   56.0   2756  5.76  5.73
# 53935  53936   0.72  Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53939  53940   0.75  Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# 11     2.46
# 13     2.71
# 16     2.68
# ...

# %%
# Printing data from the group Premium
group.get_group("Premium")
# Out:
#           no  carat      cut color clarity  depth  table  price     x     y  \
# 1          2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 3          4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 12        13   0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84
# 14        15   0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75
# 15        16   0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42
# ...      ...    ...      ...   ...     ...    ...    ...    ...   ...   ...
# 53928  53929   0.79  Premium     E     SI2   61.4   58.0   2756  6.03  5.96
# 53930  53931   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74
# 53931  53932   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73
# 53934  53935   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73
# 53938  53939   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12
#
#           z
# 1      2.31
# 3      2.63
# 12     2.33
# ...

# %%
# Printing data from the group Very Good
group.get_group("Very Good")
# Out:
#           no  carat        cut color clarity  depth  table  price     x     y  \
# 5          6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96
# 6          7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98
# 7          8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11
# 9         10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05
# 19        20   0.30  Very Good     J     SI1   62.7   59.0    351  4.21  4.27
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53921  53922   0.70  Very Good     E     VS2   62.8   60.0   2755  5.59  5.65
# 53922  53923   0.70  Very Good     D     VS1   63.1   59.0   2755  5.67  5.58
# 53932  53933   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76
# 53933  53934   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72
# 53937  53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
#
#           z
# 5      2.48
# ...

# %%
# Printing data from the group Ideal
group.get_group("Fair")
# Out:
#           no  carat   cut color clarity  depth  table  price     x     y     z
# 8          9   0.22  Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 91        92   0.86  Fair     E     SI2   55.1   69.0   2757  6.45  6.33  3.52
# 97        98   0.96  Fair     F     SI2   66.3   62.0   2759  6.27  5.95  4.07
# 123      124   0.70  Fair     F     VS2   64.5   57.0   2762  5.57  5.53  3.58
# 124      125   0.70  Fair     F     VS2   65.3   55.0   2762  5.63  5.58  3.66
# ...      ...    ...   ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53757  53758   0.72  Fair     F     VS2   55.4   64.0   2724  6.06  5.97  3.34
# 53800  53801   0.90  Fair     I     VS1   68.7   62.0   2732  5.83  5.79  3.99
# 53863  53864   1.00  Fair     I     SI2   66.8   56.0   2743  6.22  6.12  4.13
# 53879  53880   1.04  Fair     G     SI2   65.2   57.0   2745  6.25  6.23  4.07
# 53882  53883   0.71  Fair     D     VS1   65.4   59.0   2747  5.62  5.58  3.66
#
# ...

# %%
# Search in a specific column
data["clarity"].eq("SI2").any()
# Out:
# True

# %%
# Exact match
data.isin(["E"]).any(axis=1)
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Length: 53940, dtype: bool

# %%
# Search using query function
data.query("carat==0.90")
# Out:
#           no  carat        cut color clarity  depth  table  price     x     y  \
# 112      113    0.9    Premium     I     VS2   63.0   58.0   2761  6.16  6.12
# 305      306    0.9       Good     I     SI2   62.2   59.0   2800  6.07  6.11
# 307      308    0.9  Very Good     I     SI2   61.3   56.0   2800  6.17  6.23
# 352      353    0.9       Fair     I     SI1   67.3   59.0   2804  5.93  5.84
# 439      440    0.9       Fair     J     VS2   65.0   56.0   2815  6.08  6.04
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53787  53788    0.9       Good     J     SI1   63.2   60.0   2729  6.09  6.12
# 53800  53801    0.9       Fair     I     VS1   68.7   62.0   2732  5.83  5.79
# 53803  53804    0.9       Good     H     SI1   63.8   56.0   2732  6.07  6.02
# 53806  53807    0.9    Premium     H     SI2   61.1   58.0   2732  6.21  6.13
# 53917  53918    0.9  Very Good     J     SI1   63.2   60.0   2753  6.12  6.09
#
#           z
# 112    3.87
# ...

# %%
# To find the null values
data.isnull().sum().sum()
# Out:
# 0

# %%
# To find the null values in columns
data.isnull().sum()
# Out:
# no         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
# To remove the null row if the whole row contains null value
data.dropna(how="all")
# Out:
#           no  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935  53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936  53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937  53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# ...

# %%
# To remove the null row if any of the row contains null value
data.dropna(how="any")
# Out:
#           no  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935  53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936  53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937  53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# ...

# %%
# To find the duplicate values
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Length: 53940, dtype: bool

# %%
# To print the number of duplicated values
print(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Visualization using Seaborn

# %%
# Visualization using barplot

# %%
sns.barplot(x="cut",y="carat",data=data,palette="Dark2")
a={"family":"Verdana","color":"red","size":15}
b={"family":"Arial","color":"blue"}
plt.title("CUT vs CARAT BARPLOT",fontdict=a)
plt.xlabel("CUT",fontdict=b)
plt.ylabel("CARAT",fontdict=b)
plt.show()
# from this graph we can understand that fair cut has more carat than other cuts

# %%
sns.barplot(x="cut",y="depth",hue="color",palette="PuBuGn",data=data)
a={"family":"Verdana","color":"red","size":15}
b={"family":"Arial","color":"blue"}
plt.title("CUT vs DEPTH BARPLOT",fontdict=a)
plt.xlabel("CUT",fontdict=b)
plt.ylabel("DEPTH",fontdict=b)
plt.show()
# from this graph we can understand that fair cut has more depth than other cuts

# %%
sns.barplot(x="color",y="price",palette="CMRmap",data=data)
a={"family":"Verdana","color":"red","size":15}
b={"family":"Arial","color":"blue"}
plt.title("COLOR vs PRICE BARPLOT",fontdict=a)
plt.xlabel("COLOR",fontdict=b)
plt.ylabel("PRICE",fontdict=b)
plt.show()
# Color J has the most price than any other colors

# %%
# Visualization using countplot

# %%
sns.countplot(x="cut",data=data,color="yellow")
a={"family":"Verdana","color":"blue","size":15}
b={"family":"Arial","color":"green"}
plt.title("CUT COUNTPLOT",fontdict=a)
plt.xlabel("CUT",fontdict=b)
plt.ylabel("COUNT",fontdict=b)
plt.show()
# Cut ideal has more sales than other cuts

# %%
sns.countplot(x="clarity",data=data,palette="Oranges",hue="cut")
a={"family":"Verdana","color":"blue","size":15}
b={"family":"Arial","color":"green"}
plt.title("CLARITY COUNTPLOT",fontdict=a)
plt.xlabel("CLARITY",fontdict=b)
plt.ylabel("COUNT",fontdict=b)
plt.show()
# Ideal cut with VS2 clarity is mostly used one in this dataset

# %%
#Visulaization using scatterplot

# %%
sns.scatterplot(x="cut",y="table",color="red",data=data)
a={"family":"Verdana","color":"brown","size":15}
b={"family":"Arial","color":"red"}
plt.title("CUT vs TABLE SCATTERPLOT",fontdict=a)
plt.xlabel("CUT",fontdict=b)
plt.ylabel("TABLE",fontdict=b)
plt.show()
# Column table denotes width of the diamond hence it is clear that cut fair has more width

# %%
sns.scatterplot(x="clarity",y="depth",hue="cut",size="cut",data=data)
a={"family":"Verdana","color":"brown","size":15}
b={"family":"Arial","color":"red"}
plt.title("CLARITY vs DEPTH SCATTERPLOT",fontdict=a)
plt.xlabel("CLARITY",fontdict=b)
plt.ylabel("DEPTH",fontdict=b)
plt.show()
# fair cut has more depth and ideal,premium,good,very good has average depth

# %%
# Visualization using Boxplot

# %%
sns.boxplot(x="cut",y="carat",data=data)
a={"family":"Verdana","color":"green","size":15}
b={"family":"Arial","color":"blue"}
plt.title("CUT vs CARAT BOXPLOT",fontdict=a)
plt.xlabel("CUT",fontdict=b)
plt.ylabel("CARAT",fontdict=b)
plt.show()
# Median: Represent by a line with in the box, indicating the middle value of the data
# Single data points: represented by the diagonal shape inside the graph
# Lower Quartile: beginning line of the box
# Upper Quartile: End line of the box
# from this graph we can understand that fair plot have the highest single data pointz

# %%
# Visualization using Violinplot

# %%
sns.violinplot(x="cut",y="carat",data=data)
a={"family":"Verdana","color":"purple","size":15}
b={"family":"Arial","color":"maroon"}
plt.title("CUT vs CARAT VIOLINPLOT",fontdict=a)
plt.xlabel("CUT",fontdict=b)
plt.ylabel("CARAT",fontdict=b)
plt.show()
# Minimum Value: fair plot has highest minimum value but only few values
# Median: white dot inside the graph
# wider portion of the area has more points

# %% [markdown]
# # Machine Learning

# %%
data
# Out:
#           no  carat        cut color clarity  depth  table  price     x     y  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3          4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4          5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935  53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936  53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937  53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# ...

# %%
# Importing LabelEncoder to convert string values into integer values
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data["color"]=encoder.fit_transform(data["color"])
data
# Out:
#           no  carat        cut  color clarity  depth  table  price     x  \
# 0          1   0.23      Ideal      1     SI2   61.5   55.0    326  3.95
# 1          2   0.21    Premium      1     SI1   59.8   61.0    326  3.89
# 2          3   0.23       Good      1     VS1   56.9   65.0    327  4.05
# 3          4   0.29    Premium      5     VS2   62.4   58.0    334  4.20
# 4          5   0.31       Good      6     SI2   63.3   58.0    335  4.34
# ...      ...    ...        ...    ...     ...    ...    ...    ...   ...
# 53935  53936   0.72      Ideal      0     SI1   60.8   57.0   2757  5.75
# 53936  53937   0.72       Good      0     SI1   63.1   55.0   2757  5.69
# 53937  53938   0.70  Very Good      0     SI1   62.8   60.0   2757  5.66
# 53938  53939   0.86    Premium      4     SI2   61.0   58.0   2757  6.15
# 53939  53940   0.75      Ideal      0     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# ...

# %%
# Droping strings columns cut and clarity
dataset=data.drop(["cut","clarity"],axis=1)
dataset
# Out:
#           no  carat  color  depth  table  price     x     y     z
# 0          1   0.23      1   61.5   55.0    326  3.95  3.98  2.43
# 1          2   0.21      1   59.8   61.0    326  3.89  3.84  2.31
# 2          3   0.23      1   56.9   65.0    327  4.05  4.07  2.31
# 3          4   0.29      5   62.4   58.0    334  4.20  4.23  2.63
# 4          5   0.31      6   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...    ...    ...   ...   ...   ...
# 53935  53936   0.72      0   60.8   57.0   2757  5.75  5.76  3.50
# 53936  53937   0.72      0   63.1   55.0   2757  5.69  5.75  3.61
# 53937  53938   0.70      0   62.8   60.0   2757  5.66  5.68  3.56
# 53938  53939   0.86      4   61.0   58.0   2757  6.15  6.12  3.74
# 53939  53940   0.75      0   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
# As we can see the target column is not at the end of the dataset though droping the target column
dataset1=dataset.drop(["price"],axis=1)
dataset1
# Out:
#           no  carat  color  depth  table     x     y     z
# 0          1   0.23      1   61.5   55.0  3.95  3.98  2.43
# 1          2   0.21      1   59.8   61.0  3.89  3.84  2.31
# 2          3   0.23      1   56.9   65.0  4.05  4.07  2.31
# 3          4   0.29      5   62.4   58.0  4.20  4.23  2.63
# 4          5   0.31      6   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...    ...    ...    ...   ...   ...   ...
# 53935  53936   0.72      0   60.8   57.0  5.75  5.76  3.50
# 53936  53937   0.72      0   63.1   55.0  5.69  5.75  3.61
# 53937  53938   0.70      0   62.8   60.0  5.66  5.68  3.56
# 53938  53939   0.86      4   61.0   58.0  6.15  6.12  3.74
# 53939  53940   0.75      0   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 8 columns]

# %%
# Dataset converting into DataFrame using (.values)
x=dataset1.iloc[:,:].values
x
# Out:
# array([[1.0000e+00, 2.3000e-01, 1.0000e+00, ..., 3.9500e+00, 3.9800e+00,
#         2.4300e+00],
#        [2.0000e+00, 2.1000e-01, 1.0000e+00, ..., 3.8900e+00, 3.8400e+00,
#         2.3100e+00],
#        [3.0000e+00, 2.3000e-01, 1.0000e+00, ..., 4.0500e+00, 4.0700e+00,
#         2.3100e+00],
#        ...,
#        [5.3938e+04, 7.0000e-01, 0.0000e+00, ..., 5.6600e+00, 5.6800e+00,
#         3.5600e+00],
#        [5.3939e+04, 8.6000e-01, 4.0000e+00, ..., 6.1500e+00, 6.1200e+00,
#         3.7400e+00],
#        [5.3940e+04, 7.5000e-01, 0.0000e+00, ..., 5.8300e+00, 5.8700e+00,
#         3.6400e+00]])

# %%
# Converting target data into DataFrame
y=dataset.iloc[:,5].values
y
# Out:
# array([ 326,  326,  327, ..., 2757, 2757, 2757], dtype=int64)

# %%
# Splitting the data for training and testing
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
xtrain
# Out:
# array([[2.6251e+04, 1.6300e+00, 3.0000e+00, ..., 7.5600e+00, 7.6000e+00,
#         4.6800e+00],
#        [3.1511e+04, 3.4000e-01, 3.0000e+00, ..., 4.4700e+00, 4.4400e+00,
#         2.7700e+00],
#        [4.0699e+04, 4.0000e-01, 1.0000e+00, ..., 4.7300e+00, 4.7700e+00,
#         2.9300e+00],
#        ...,
#        [4.2614e+04, 3.2000e-01, 5.0000e+00, ..., 4.3500e+00, 4.3900e+00,
#         2.6800e+00],
#        [4.3568e+04, 4.1000e-01, 3.0000e+00, ..., 4.8100e+00, 4.7900e+00,
#         2.9300e+00],
#        [2.7330e+03, 9.1000e-01, 2.0000e+00, ..., 6.2400e+00, 6.1900e+00,
#         3.8000e+00]])

# %%
xtest
# Out:
# array([[1.0177e+04, 1.1000e+00, 4.0000e+00, ..., 6.6100e+00, 6.6500e+00,
#         4.1100e+00],
#        [1.6084e+04, 1.2900e+00, 4.0000e+00, ..., 6.9600e+00, 6.9300e+00,
#         4.3500e+00],
#        [1.3421e+04, 1.2000e+00, 5.0000e+00, ..., 6.8800e+00, 6.8000e+00,
#         4.1800e+00],
#        ...,
#        [5.5090e+03, 1.0800e+00, 2.0000e+00, ..., 6.5300e+00, 6.5000e+00,
#         4.1300e+00],
#        [1.9536e+04, 1.0200e+00, 3.0000e+00, ..., 6.4400e+00, 6.4700e+00,
#         3.9700e+00],
#        [4.7951e+04, 5.0000e-01, 1.0000e+00, ..., 4.9700e+00, 5.0000e+00,
#         3.2300e+00]])

# %%
ytrain
# Out:
# array([15697,   765,  1158, ...,   505,  1431,  3246], dtype=int64)

# %%
ytest
# Out:
# array([4733, 6424, 5510, ..., 3847, 8168, 1917], dtype=int64)

# %%
# Fitting the LinearRegression model into training set
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
# Predicting LinearRegression for training set
xpred=regression.predict(xtrain)
xpred
# Out:
# array([11041.25684107,   306.47702287,  1443.75238418, ...,
#         -126.22991131,   990.25933338,  4890.216759  ])

# %%
# Predicting LinearRegression for testing set
ypred=regression.predict(xtest)
ypred
# Out:
# array([5915.05247389, 7407.34777902, 6304.04675093, ..., 5999.58079343,
#        5452.32194212, 1513.52269119])

# %%
# Importing metrics from sklearn for error calculation
from sklearn import metrics

# %%
# Printing Train Score, Test Score, Mean Absolute Error, Mean Squared Error, Root Mean Squared Error of LinearRegression
print("Train Score",regression.score(xtrain,ytrain))
print("Test Score",regression.score(xtest,ytest))
print("Mean Abosulte Error",metrics.mean_absolute_error(ytest,ypred))
print("Mean Squared Error",metrics.mean_squared_error(ytest,ypred))
print("Root Mean Squared Error",np.sqrt(metrics.mean_squared_error(ytest,ypred)))
# Out:
# Train Score 0.8702770504579593
# Test Score 0.8734260119510244
# Mean Abosulte Error 894.3790931441742
# Mean Squared Error 2006410.3983231117
# Root Mean Squared Error 1416.4781672595986

# %%
# Fitting DecisionTreeRegressor in training set
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
# Predicting DecisionTreeRegressor for training set
xpred1=dtr.predict(xtrain)
xpred1
# Out:
# array([15697.,   765.,  1158., ...,   505.,  1431.,  3246.])

# %%
# Predicting DecisionTreeRegressor for test set
ypred1=dtr.predict(xtest)
ypred1
# Out:
# array([4732., 6421., 5510., ..., 3846., 8169., 1917.])

# %%
# Printing Train Score, Test Score, Mean Absolute Error, Mean Squared Error, Root Mean Squared Error of DecisionTreeRegression 
print("Train Score",dtr.score(xtrain,ytrain))
print("Test Score",dtr.score(xtest,ytest))
print("Mean Absolute Error",metrics.mean_absolute_error(ytest,ypred1))
print("Mean Squared Error",metrics.mean_squared_error(ytest,ypred1))
print("Root Mean Squared Error",np.sqrt(metrics.mean_squared_error(ytest,ypred1)))
# Out:
# Train Score 1.0
# Test Score 0.9997396401755188
# Mean Absolute Error 5.166110493140526
# Mean Squared Error 4127.140711902113
# Root Mean Squared Error 64.24282615126855

# %%
# Fitting RandomForestRegressor in training set
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor()

# %%
# Predicting RandomForestRegressor for training set
xpred2=rfr.predict(xtrain)
xpred2
# Out:
# array([15697.9 ,   765.  ,  1158.  , ...,   505.09,  1431.  ,  3246.11])

# %%
# Predicting RandomForestRegressor for test set
ypred2=rfr.predict(xtest)
ypred2
# Out:
# array([4732.66, 6424.8 , 5510.18, ..., 3846.64, 8168.3 , 1889.  ])

# %%
# Printing Train Score, Test Score, Mean Absolute Error, Mean Squared Error, Root Mean Squared Error of RandomForestRegressor
print("Train Score",rfr.score(xtrain,ytrain))
print("Test Score",rfr.score(xtest,ytest))
print("Mean Absolute Error",metrics.mean_absolute_error(ytest,ypred2))
print("Mean Squared Error",metrics.mean_squared_error(ytest,ypred2))
print("Root Mean Squared Error",np.sqrt(metrics.mean_squared_error(ytest,ypred)))
# Out:
# Train Score 0.9999859679286619
# Test Score 0.9998891889968415
# Mean Absolute Error 5.261700964034122
# Mean Squared Error 1756.5406005839825
# Root Mean Squared Error 1416.4781672595986

# %%
# Fitting GaussianNB in training set
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %%
# Predicting GaussianNB for training set
xpred4=nb.predict(xtrain)
xpred4
# Out:
# array([15697,   765,  1158, ...,   505,  1431,  3246], dtype=int64)

# %%
# Predicting GaussianNB for test set
ypred4=nb.predict(xtest)
ypred4
# Out:
# array([4732, 6424, 5510, ..., 3846, 8167, 1917], dtype=int64)

# %%
# Printing Train Score, Test Score, Mean Absolute Error, Mean Squared Error, Root Mean Squared Error of GaussianNB
print("Train Score",nb.score(xtrain,ytrain))
print("Test Score",nb.score(xtest,ytest))
print("Mean Absolute Error",metrics.mean_absolute_error(ytest,ypred4))
print("Mean Squared Error",metrics.mean_squared_error(ytest,ypred4))
print("Root Mean Absolute Error",np.sqrt(metrics.mean_absolute_error(ytest,ypred4)))
# Out:
# Train Score 0.9617398961809418
# Test Score 0.6703744901742678
# Mean Absolute Error 124.03791249536522
# Mean Squared Error 1077512.3458472376
# Root Mean Absolute Error 11.137230916855644

# %%
a=regression.score(xtest,ytest)
a
# Out:
# 0.8734260119510244

# %%
b=dtr.score(xtest,ytest)
b
# Out:
# 0.9997396401755188

# %%
c=rfr.score(xtest,ytest)
c
# Out:
# 0.9998891889968415

# %%
d=nb.score(xtest,ytest)
d
# Out:
# 0.6703744901742678

# %%
# Converting ML Models into a DataFrame
x=pd.DataFrame({"ML Models":["Linear Regression","Decision Tree Regression","Random Forest Regression","GaussianNB"],
               "Test Score":[a,b,c,d]})
x
# Out:
#                   ML Models  Test Score
# 0         Linear Regression    0.873426
# 1  Decision Tree Regression    0.999740
# 2  Random Forest Regression    0.999889
# 3                GaussianNB    0.670374

# %%
# Drawing barplot using ML Models
sns.barplot(x="ML Models",y="Test Score",data=x,color="green")
a={"family":"Verdana","color":"brown","size":15}
b={"family":"Arial","color":"red"}
plt.xlabel("ML Models",fontdict=a)
plt.ylabel("Test Score",fontdict=b)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # CONCLUSION

# %%
# From this diamond price prediction dataset we can undertsand that RandomForestRegressor has more test score than others regressions
